# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\athen\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv("../data/Cleaned_2018_Flights.csv")

# %%
np.sort(data['OriginWac'].unique())
# Out:
# array([ 1,  2,  3,  4,  5, 11, 12, 13, 14, 15, 16, 21, 22, 23, 33, 34, 35,
#        36, 37, 38, 39, 41, 42, 43, 44, 45, 51, 52, 53, 54, 61, 62, 63, 64,
#        65, 66, 67, 71, 72, 73, 74, 81, 82, 83, 84, 85, 86, 87, 88, 91, 92,
#        93], dtype=int64)

# %%
data[:100000].plot.scatter(x = "Miles", y = "PricePerTicket", figsize = (10, 10))
